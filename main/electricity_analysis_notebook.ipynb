# %%
"""
Helper script to import functions from electricity_analysis.py
Use this in your notebook to easily access the analysis functions
"""

import sys
import os

# Add the parent directory to the path
sys.path.append('.')

# Import all functions from electricity_analysis
from electricity_analysis import ea

# Also import common data science libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
from icecream import ic
warnings.filterwarnings('ignore')

print("✅ All functions imported successfully!")
print("Available functions:")
print("- load_electricity_data(path)")
print("- analyze_data(df)")
print("- create_visualizations(df)")
print("- analyze_patterns(df)")
print("- generate_summary(df)")
# Out:
# ✅ All functions imported successfully!
# Available functions:
# - load_electricity_data(path)
# - analyze_data(df)
# - create_visualizations(df)
# - analyze_patterns(df)
# - generate_summary(df)

# %%
root_path = "/home/philg/projects/stratcon"
path = f"{root_path}/downloads/Gigawatt Power Inc/Electricity consumption - 2025-01-31 - 2025-07-01 - 5 minutes.csv"
df = ea.load_and_prepare_data(path)
ea.check_data_completeness(df, strict = False)

# %%
print(df.columns)
df.head()
# Out:
# Index(['Consumption [kW]', 'Production [kW]', 'Always on [kW]', 'Import [kW]',
#        'Export [kW]', 'Date', 'Month', 'Year', 'Hour', 'Day', 'DayOfWeek'],
#       dtype='object')
#                      Consumption [kW]  Production [kW]  Always on [kW]  \
# Timestamp
# 2025-01-31 00:00:00             3.669           -0.018           3.019
# 2025-01-31 00:05:00             5.357           -0.018           3.019
# 2025-01-31 00:10:00             6.085           -0.018           3.019
# 2025-01-31 00:15:00             5.997           -0.018           3.019
# 2025-01-31 00:20:00             6.007           -0.018           3.019
#
#                      Import [kW]  Export [kW]        Date  Month  Year  Hour  \
# Timestamp
# 2025-01-31 00:00:00        3.687          0.0  2025-01-31      1  2025     0
# 2025-01-31 00:05:00        5.375          0.0  2025-01-31      1  2025     0
# 2025-01-31 00:10:00        6.104          0.0  2025-01-31      1  2025     0
# 2025-01-31 00:15:00        6.015          0.0  2025-01-31      1  2025     0
# 2025-01-31 00:20:00        6.025          0.0  2025-01-31      1  2025     0
#
#                      Day  DayOfWeek
# Timestamp
# 2025-01-31 00:00:00   31          4
# 2025-01-31 00:05:00   31          4
# 2025-01-31 00:10:00   31          4
# 2025-01-31 00:15:00   31          4
# 2025-01-31 00:20:00   31          4

# %%
df = ea.init_interval_and_alarm_levels(df)
df.head()
# Out:
#                      Consumption [kW]  Production [kW]  Always on [kW]  \
# Timestamp
# 2025-01-31 00:00:00             3.669           -0.018           3.019
# 2025-01-31 00:05:00             5.357           -0.018           3.019
# 2025-01-31 00:10:00             6.085           -0.018           3.019
# 2025-01-31 00:15:00             5.997           -0.018           3.019
# 2025-01-31 00:20:00             6.007           -0.018           3.019
#
#                      Import [kW]  Export [kW]        Date  Month  Year  Hour  \
# Timestamp
# 2025-01-31 00:00:00        3.687          0.0  2025-01-31      1  2025     0
# 2025-01-31 00:05:00        5.375          0.0  2025-01-31      1  2025     0
# 2025-01-31 00:10:00        6.104          0.0  2025-01-31      1  2025     0
# 2025-01-31 00:15:00        6.015          0.0  2025-01-31      1  2025     0
# 2025-01-31 00:20:00        6.025          0.0  2025-01-31      1  2025     0
#
#                      Day  DayOfWeek  Interval_minutes  \
# Timestamp
# 2025-01-31 00:00:00   31          4               NaN
# 2025-01-31 00:05:00   31          4               5.0
# 2025-01-31 00:10:00   31          4               5.0
# 2025-01-31 00:15:00   31          4               5.0
# 2025-01-31 00:20:00   31          4               5.0
#
#                      Nb_of_intervals_between_timestamps  \
# Timestamp
# 2025-01-31 00:00:00                                 NaN
# 2025-01-31 00:05:00                                 1.0
# 2025-01-31 00:10:00                                 1.0
# 2025-01-31 00:15:00                                 1.0
# 2025-01-31 00:20:00                                 1.0
#
#                      Missing_timestamps_after_timestamp
# Timestamp
# 2025-01-31 00:00:00                                 NaN
# 2025-01-31 00:05:00                                 0.0
# 2025-01-31 00:10:00                                 0.0
# 2025-01-31 00:15:00                                 0.0
# 2025-01-31 00:20:00                                 0.0

# %%
df = ea.select_full_months(df)
df.head()
# Out:
#                      Consumption [kW]  Production [kW]  Always on [kW]  \
# Timestamp
# 2025-02-01 00:00:00             6.163           -0.019           2.805
# 2025-02-01 00:05:00             6.151           -0.019           2.805
# 2025-02-01 00:10:00             6.090           -0.019           2.805
# 2025-02-01 00:15:00             6.281           -0.019           2.805
# 2025-02-01 00:20:00             6.319           -0.019           2.805
#
#                      Import [kW]  Export [kW]        Date  Month  Year  Hour  \
# Timestamp
# 2025-02-01 00:00:00        6.182          0.0  2025-02-01      2  2025     0
# 2025-02-01 00:05:00        6.170          0.0  2025-02-01      2  2025     0
# 2025-02-01 00:10:00        6.109          0.0  2025-02-01      2  2025     0
# 2025-02-01 00:15:00        6.300          0.0  2025-02-01      2  2025     0
# 2025-02-01 00:20:00        6.338          0.0  2025-02-01      2  2025     0
#
#                      Day  DayOfWeek  Interval_minutes  \
# Timestamp
# 2025-02-01 00:00:00    1          5               5.0
# 2025-02-01 00:05:00    1          5               5.0
# 2025-02-01 00:10:00    1          5               5.0
# 2025-02-01 00:15:00    1          5               5.0
# 2025-02-01 00:20:00    1          5               5.0
#
#                      Nb_of_intervals_between_timestamps  \
# Timestamp
# 2025-02-01 00:00:00                                 1.0
# 2025-02-01 00:05:00                                 1.0
# 2025-02-01 00:10:00                                 1.0
# 2025-02-01 00:15:00                                 1.0
# 2025-02-01 00:20:00                                 1.0
#
#                      Missing_timestamps_after_timestamp
# Timestamp
# 2025-02-01 00:00:00                                 0.0
# 2025-02-01 00:05:00                                 0.0
# 2025-02-01 00:10:00                                 0.0
# 2025-02-01 00:15:00                                 0.0
# 2025-02-01 00:20:00                                 0.0

# %%
ea.check_data_completeness(df, strict = False)

# %%
df = ea.compute_energy(df)
df.head()
# Out:
#                      Consumption [kW]  Production [kW]  Always on [kW]  \
# Timestamp
# 2025-02-01 00:00:00             6.163           -0.019           2.805
# 2025-02-01 00:05:00             6.151           -0.019           2.805
# 2025-02-01 00:10:00             6.090           -0.019           2.805
# 2025-02-01 00:15:00             6.281           -0.019           2.805
# 2025-02-01 00:20:00             6.319           -0.019           2.805
#
#                      Import [kW]  Export [kW]        Date  Month  Year  Hour  \
# Timestamp
# 2025-02-01 00:00:00        6.182          0.0  2025-02-01      2  2025     0
# 2025-02-01 00:05:00        6.170          0.0  2025-02-01      2  2025     0
# 2025-02-01 00:10:00        6.109          0.0  2025-02-01      2  2025     0
# 2025-02-01 00:15:00        6.300          0.0  2025-02-01      2  2025     0
# 2025-02-01 00:20:00        6.338          0.0  2025-02-01      2  2025     0
#
#                      Day  ...  Missing_timestamps_after_timestamp  \
# Timestamp                 ...
# 2025-02-01 00:00:00    1  ...                                 0.0
# 2025-02-01 00:05:00    1  ...                                 0.0
# 2025-02-01 00:10:00    1  ...                                 0.0
# 2025-02-01 00:15:00    1  ...                                 0.0
# 2025-02-01 00:20:00    1  ...                                 0.0
#
#                      Alarm_consecutive_missing_timestamps  \
# Timestamp
# 2025-02-01 00:00:00                                 False
# 2025-02-01 00:05:00                                 False
# 2025-02-01 00:10:00                                 False
# 2025-02-01 00:15:00                                 False
# 2025-02-01 00:20:00                                 False
#
#                      Mean_power_consumption_per_interval [kW]  \
# Timestamp
# 2025-02-01 00:00:00                                    6.1570
# 2025-02-01 00:05:00                                    6.1205
# 2025-02-01 00:10:00                                    6.1855
# 2025-02-01 00:15:00                                    6.3000
# 2025-02-01 00:20:00                                    6.1855
#
#                      Mean_power_production_per_interval [kW]  \
# Timestamp
# 2025-02-01 00:00:00                                   -0.019
# 2025-02-01 00:05:00                                   -0.019
# 2025-02-01 00:10:00                                   -0.019
# 2025-02-01 00:15:00                                   -0.019
# 2025-02-01 00:20:00                                   -0.019
#
#                      Mean_power_import_per_interval [kW]  \
# Timestamp
# 2025-02-01 00:00:00                               6.1760
# 2025-02-01 00:05:00                               6.1395
# 2025-02-01 00:10:00                               6.2045
# 2025-02-01 00:15:00                               6.3190
# 2025-02-01 00:20:00                               6.2040
#
#                      Mean_power_export_per_interval [kW]  \
# Timestamp
# 2025-02-01 00:00:00                                  0.0
# 2025-02-01 00:05:00                                  0.0
# 2025-02-01 00:10:00                                  0.0
# 2025-02-01 00:15:00                                  0.0
# 2025-02-01 00:20:00                                  0.0
#
#                      Energy_consumption_per_interval [kWh]  \
# Timestamp
# 2025-02-01 00:00:00                               0.513083
# 2025-02-01 00:05:00                               0.510042
# 2025-02-01 00:10:00                               0.515458
# 2025-02-01 00:15:00                               0.525000
# 2025-02-01 00:20:00                               0.515458
#
#                      Energy_production_per_interval [kWh]  \
# Timestamp
# 2025-02-01 00:00:00                             -0.001583
# 2025-02-01 00:05:00                             -0.001583
# 2025-02-01 00:10:00                             -0.001583
# 2025-02-01 00:15:00                             -0.001583
# 2025-02-01 00:20:00                             -0.001583
#
#                      Energy_import_per_interval [kWh]  \
# Timestamp
# 2025-02-01 00:00:00                          0.514667
# 2025-02-01 00:05:00                          0.511625
# 2025-02-01 00:10:00                          0.517042
# 2025-02-01 00:15:00                          0.526583
# 2025-02-01 00:20:00                          0.517000
#
#                      Energy_export_per_interval [kWh]
# Timestamp
# 2025-02-01 00:00:00                               0.0
# 2025-02-01 00:05:00                               0.0
# 2025-02-01 00:10:00                               0.0
# 2025-02-01 00:15:00                               0.0
# 2025-02-01 00:20:00                               0.0
#
# [5 rows x 23 columns]

# %%
ea.generate_summary_energy(df)
# Out:
# (None,
#  None,
#  '<h1>Report Summary</h1><pre>\n-- Comparison of Consumption per month --\nTotal Consumption latest month: 16094.30 kWh\nAverage Consumption previous months: 17096.54 kWh\nMax Consumption previous months: 18968.31 kWh\nMin Consumption previous months: 13854.27 kWh\nDelta vs previous month - Consumption: -1002.24 kWh\n\n-- Comparison of Production per month --\nTotal Production latest month: 2205.52 kWh\nAverage Production previous months: 2556.79 kWh\nMax Production previous months: 2995.42 kWh\nMin Production previous months: 1917.62 kWh\nDelta vs previous month - Production: -351.27 kWh\n\n-- Comparison of Import per month --\nTotal Import latest month: 13888.80 kWh\nAverage Import previous months: 14539.77 kWh\nMax Import previous months: 15972.96 kWh\nMin Import previous months: 11936.67 kWh\nDelta vs previous month - Import: -650.97 kWh\n\n-- Comparison of Export per month --\nTotal Export latest month: 0.00 kWh\nAverage Export previous months: 0.01 kWh\nMax Export previous months: 0.05 kWh\nMin Export previous months: 0.00 kWh\nDelta vs previous month - Export: -0.01 kWh\n</pre>',
#  '<h1>Report Summary</h1><pre>\n--- Comparison of Consumption per day ---\nAverage Consumption daily consumption: 534.47 kWh\nMax Consumption daily consumption: 749.00 kWh\nMin Consumption daily consumption: 291.09 kWh\n\n--- Comparison of Production per day ---\nAverage Production daily consumption: 73.26 kWh\nMax Production daily consumption: 113.02 kWh\nMin Production daily consumption: 33.98 kWh\n\n--- Comparison of Import per day ---\nAverage Import daily consumption: 461.22 kWh\nMax Import daily consumption: 635.99 kWh\nMin Import daily consumption: 255.04 kWh\n\n--- Comparison of Export per day ---\nAverage Export daily consumption: 0.00 kWh\nMax Export daily consumption: 0.00 kWh\nMin Export daily consumption: 0.00 kWh\n</pre>')

# %%
ea.run()

# %%
# !ls -lh
# Out:
# total 9.1M
# drwxr-xr-x 2 philg philg 4.0K Jul 21 15:54 __pycache__
# -rw-r--r-- 1 philg philg  29K Jul 21 15:54 electricity_analysis.py
# -rw-r--r-- 1 philg philg  62K Jul 19 18:38 electricity_analysis_notebook.ipynb
# -rw-r--r-- 1 philg philg 4.5M Jul 21 15:54 energy_consumption_per_day.html
# -rw-r--r-- 1 philg philg 4.5M Jul 21 15:54 energy_consumption_per_month.html
# -rw-r--r-- 1 philg philg    1 Jul 18 10:35 test_import.ipynb
